# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Riccardo Mancone**
# CEO

# %% [markdown]
# _I'm interested in data science because working with data could create social welfare_

# %% [markdown]
# ### the code will add 1 with 1

# %%
print (1+1)
# Out:
# 2

# %% [markdown]
# ## Dioporco
#
# _tabella giocatori_
#
# lista droghe
# * maria
# * coca
# * lean
#
# | nome | cognome | id |
# | - | - | - |
# | Davide | Mancinelli | 22 |
# |Valentino|Rossi|46|
# |Francesco|Totti|10|
#
# [Greatest atlete of all time](https://it.wikipedia.org/wiki/Cristiano_Ronaldo "SIUUUUUU")
#
#
# ![God of football](https://i2-prod.football.london/incoming/article25783675.ece/ALTERNATES/s615/0_GettyImages-1450108295.jpg "GOAT")
#
# https://it.wikipedia.org/wiki/Cristiano_Ronaldo
#
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
